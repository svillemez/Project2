# %%
import pandas as pd
import numpy as np
import requests
import json
from datetime import timedelta, date, datetime
from config import api_key
from pprint import pprint

# %% [markdown]
# Important note on this API call and dataset!! NYT has very strict and specific limit restrictions. All data has been saved to .csv files. If you DO NEED to use this code to hit the api wait no less than one minute between requests.

# %%
base_url = "https://api.nytimes.com/svc/books/v3"
tail = f"?api-key={api_key}"

# %%
#since we are expanding our scope i need a date calculator to generate a list of weeks
weeks_in_bc=[] 
counter = 0
week = timedelta(days=7)
start=datetime.strptime('2019 12 29', '%Y %m %d').date()

# %%
while counter < 39:
    pub_date = (start+week)
    pubdateform = pub_date.isoformat()
    weeks_in_bc.append(pubdateform)
    start = pub_date
    if counter > 39:
        break
    counter += 1

# %%
#Variables for lists/API call
result_count=np.arange(15)
list_name=[]
publish_date=[]
title_name=[]
author_name=[]
weeks_on_list=[]
description=[]
publishers=[]
current_rank=[]
#not used in df still figuring out
isbns=[]
prisbn10=[]
prisbn13=[]

# %%
for week in weeks_in_bc[:10]:
    response = requests.get(f"{base_url}/lists/{week}/combined-print-and-e-book-fiction.json{tail}")
    data=response.json()
    try:   
        for i in result_count:
            listname = data['results']['list_name']
            list_name.append(listname)
            pub_date = data['results']['published_date']
            publish_date.append(pub_date)
            title = data['results']['books'][i]['title']
            title_name.append(title)
            author = data['results']['books'][i]['author']
            author_name.append(author)
            weeks = data['results']['books'][i]['weeks_on_list']
            weeks_on_list.append(weeks)
            isbnlist = data['results']['books'][i]['isbns']
            isbns.append(isbnlist)
            desc = data['results']['books'][i]['description']
            description.append(desc)
            rank = data['results']['books'][i]['rank']
            current_rank.append(rank)
            pub = data['results']['books'][i]['publisher']
            publishers.append(pub)
            isbn10 = data['results']['books'][i]['primary_isbn10']
            prisbn10.append(isbn10)
            isbn13 = data['results']['books'][i]['primary_isbn13']
            prisbn13.append(isbn13)       
            
    except KeyError as key:
        print(key)

# %%
for week in weeks_in_bc[10:20]:
    response = requests.get(f"{base_url}/lists/{week}/combined-print-and-e-book-fiction.json{tail}")
    data=response.json()
    try:   
        for i in result_count:
            listname = data['results']['list_name']
            list_name.append(listname)
            pub_date = data['results']['published_date']
            publish_date.append(pub_date)
            title = data['results']['books'][i]['title']
            title_name.append(title)
            author = data['results']['books'][i]['author']
            author_name.append(author)
            weeks = data['results']['books'][i]['weeks_on_list']
            weeks_on_list.append(weeks)
            isbnlist = data['results']['books'][i]['isbns']
            isbns.append(isbnlist)
            desc = data['results']['books'][i]['description']
            description.append(desc)
            rank = data['results']['books'][i]['rank']
            current_rank.append(rank)
            pub = data['results']['books'][i]['publisher']
            publishers.append(pub)
            isbn10 = data['results']['books'][i]['primary_isbn10']
            prisbn10.append(isbn10)
            isbn13 = data['results']['books'][i]['primary_isbn13']
            prisbn13.append(isbn13)       
            
    except KeyError as key:
        print(key)

# %%
for week in weeks_in_bc[20:30]:
    response = requests.get(f"{base_url}/lists/{week}/combined-print-and-e-book-fiction.json{tail}")
    data=response.json()
    try:   
        for i in result_count:
            listname = data['results']['list_name']
            list_name.append(listname)
            pub_date = data['results']['published_date']
            publish_date.append(pub_date)
            title = data['results']['books'][i]['title']
            title_name.append(title)
            author = data['results']['books'][i]['author']
            author_name.append(author)
            weeks = data['results']['books'][i]['weeks_on_list']
            weeks_on_list.append(weeks)
            isbnlist = data['results']['books'][i]['isbns']
            isbns.append(isbnlist)
            desc = data['results']['books'][i]['description']
            description.append(desc)
            rank = data['results']['books'][i]['rank']
            current_rank.append(rank)
            pub = data['results']['books'][i]['publisher']
            publishers.append(pub)
            isbn10 = data['results']['books'][i]['primary_isbn10']
            prisbn10.append(isbn10)
            isbn13 = data['results']['books'][i]['primary_isbn13']
            prisbn13.append(isbn13)       
            
    except KeyError as key:
        print(key)

# %%
for week in weeks_in_bc[30:]:
    response = requests.get(f"{base_url}/lists/{week}/combined-print-and-e-book-fiction.json{tail}")
    data=response.json()
    try:   
        for i in result_count:
            listname = data['results']['list_name']
            list_name.append(listname)
            pub_date = data['results']['published_date']
            publish_date.append(pub_date)
            title = data['results']['books'][i]['title']
            title_name.append(title)
            author = data['results']['books'][i]['author']
            author_name.append(author)
            weeks = data['results']['books'][i]['weeks_on_list']
            weeks_on_list.append(weeks)
            isbnlist = data['results']['books'][i]['isbns']
            isbns.append(isbnlist)
            desc = data['results']['books'][i]['description']
            description.append(desc)
            rank = data['results']['books'][i]['rank']
            current_rank.append(rank)
            pub = data['results']['books'][i]['publisher']
            publishers.append(pub)
            isbn10 = data['results']['books'][i]['primary_isbn10']
            prisbn10.append(isbn10)
            isbn13 = data['results']['books'][i]['primary_isbn13']
            prisbn13.append(isbn13)       
            
    except KeyError as key:
        print(key)

# %%
fiction_df=pd.DataFrame({
    "List": list_name,
    "List_Date": publish_date,
    "Title": title_name,
    "Author": author_name,
    "Weeks_On_List": weeks_on_list,
    "Rank_This_Week": current_rank,
    "Publisher": publishers,
    "Primary_ISBN_10": prisbn10,
    "Primary_ISBN_13": prisbn13,
    "Description" : description
})

# %%
fiction_df
# Out:
#                                   List   List_Date                     Title  \
# 0    Combined Print and E-Book Fiction  2020-01-05   WHERE THE CRAWDADS SING
# 1    Combined Print and E-Book Fiction  2020-01-05             THE GUARDIANS
# 2    Combined Print and E-Book Fiction  2020-01-05               CRISS CROSS
# 3    Combined Print and E-Book Fiction  2020-01-05             THE INSTITUTE
# 4    Combined Print and E-Book Fiction  2020-01-05      A MINUTE TO MIDNIGHT
# ..                                 ...         ...                       ...
# 580  Combined Print and E-Book Fiction  2020-09-27  THE LYING LIFE OF ADULTS
# 581  Combined Print and E-Book Fiction  2020-09-27          THICK AS THIEVES
# 582  Combined Print and E-Book Fiction  2020-09-27      TRANSCENDENT KINGDOM
# 583  Combined Print and E-Book Fiction  2020-09-27            SUCH A FUN AGE
# 584  Combined Print and E-Book Fiction  2020-09-27             AMERICAN DIRT
#
#               Author  Weeks_On_List  Rank_This_Week        Publisher  \
# 0        Delia Owens             67               1           Putnam
# 1       John Grisham             10               2        Doubleday
# 2    James Patterson              4               3    Little, Brown
# 3       Stephen King             15               4         Scribner
# 4     David Baldacci              5               5    Grand Central
# ..               ...            ...             ...              ...
# 580   Elena Ferrante              2              11  Europa Editions
# 581     Sandra Brown              3              12    Grand Central
# 582        Yaa Gyasi              2              13            Knopf
# 583       Kiley Reid             10              14           Putnam
# 584  Jeanine Cummins             34              15         Flatiron
#
#     Primary_ISBN_10 Primary_ISBN_13  \
# 0        0735219095   9780735219090
# 1        0385544189   9780385544184
# 2        0316526886   9780316526883
# 3        1982110562   9781982110567
# 4        1538761602   9781538761601
# ..              ...             ...
# 580      1609455916   9781609455910
# 581      1538751941   9781538751947
# 582      0525658181   9780525658184
# 583      0525541926   9780525541929
# 584      1250209765   9781250209764
#
#                                            Description
# 0    In a quiet town on the North Carolina coast in...
# 1    Cullen Post, a lawyer and Episcopal minister, ...
# 2    The 27th book in the Alex Cross series. Copyca...
# 3    Children with special talents are abducted and...
# 4    When Atlee Pine returns to her hometown to inv...
# ..                                                 ...
# 580  In this coming-of-age story, Giovanna seeks he...
# 581  Arden Maxwell returns home to uncover the trut...
# 582  A Ph.D. candidate in neuroscience looks to the...
# 583  Tumult ensues when Alix Chamberlain’s babysitt...
# 584  A bookseller flees Mexico for the United State...
#
# [585 rows x 10 columns]

# %%
fiction_df.to_csv("fiction.csv",index=False)

# %%
fiction_df["Title"].nunique()
# Out:
# 168

# %%
fiction_titles = list(fiction_df["Title"].unique())

# %%
#getting ONLY ONE entry for each title with it's most recent number of weeks on the list

# %%
test_df = fiction_df.copy().sort_values(by=["Title","Weeks_On_List"], ascending=False)

# %%
only_fict_titles_df = test_df.copy().drop_duplicates(subset="Title", keep="first", inplace=False)

# %%
only_fict_titles_df = only_fict_titles_df.sort_values(by="Weeks_On_List", ascending=False)

# %%
only_fict_titles_df
# Out:
#                                   List   List_Date  \
# 575  Combined Print and E-Book Fiction  2020-09-27
# 554  Combined Print and E-Book Fiction  2020-09-13
# 263  Combined Print and E-Book Fiction  2020-05-03
# 72   Combined Print and E-Book Fiction  2020-02-02
# 538  Combined Print and E-Book Fiction  2020-09-06
# ..                                 ...         ...
# 338  Combined Print and E-Book Fiction  2020-06-07
# 572  Combined Print and E-Book Fiction  2020-09-27
# 135  Combined Print and E-Book Fiction  2020-03-08
# 446  Combined Print and E-Book Fiction  2020-07-26
# 173  Combined Print and E-Book Fiction  2020-03-22
#
#                           Title                              Author  \
# 575     WHERE THE CRAWDADS SING                         Delia Owens
# 554     LITTLE FIRES EVERYWHERE                          Celeste Ng
# 263  THE TATTOOIST OF AUSCHWITZ                      Heather Morris
# 72         BEFORE WE WERE YOURS                        Lisa Wingate
# 538          THE SILENT PATIENT                    Alex Michaelides
# ..                          ...                                 ...
# 338          ON OCEAN BOULEVARD                   Mary Alice Monroe
# 572                  ONE BY ONE                           Ruth Ware
# 135              ONE MINUTE OUT                        Mark Greaney
# 446                    OUTSIDER                      Linda Castillo
# 173           YOU ARE NOT ALONE  Greer Hendricks and Sarah Pekkanen
#
#      Weeks_On_List  Rank_This_Week      Publisher Primary_ISBN_10  \
# 575            105               6         Putnam      0735219095
# 554             81              15  Penguin Press      0735224315
# 263             70               9         Harper      0062797166
# 72              53              13     Ballantine      0425284700
# 538             36              14        Celadon      1250301696
# ..             ...             ...            ...             ...
# 338              1               9        Gallery      1982146958
# 572              1               3  Gallery/Scout      150118881X
# 135              1               1        Berkley      0593098927
# 446              1              12   St. Martin's      1250142911
# 173              1               9   St. Martin's      1250202035
#
#     Primary_ISBN_13                                        Description
# 575   9780735219090  In a quiet town on the North Carolina coast in...
# 554   9780735224315   An artist upends a quiet town outside Cleveland.
# 263   9780062797162  A concentration camp detainee tasked with perm...
# 72    9780425284704  A South Carolina lawyer learns about the quest...
# 538   9781250301697  Theo Faber looks into the mystery of a famous ...
# ..              ...                                                ...
# 338   9781982146955  As her second wedding approaches, a woman retu...
# 572   9781501188817  An avalanche tests the bonds of coworkers from...
# 135   9780593098929  The ninth book in the Gray Man series. Court G...
# 446   9781250142917  The 12th book in the Kate Burkholder series. A...
# 173   9781250202031  Shay Miller’s bad luck may get even worse when...
#
# [168 rows x 10 columns]

# %%
only_fict_titles_df.to_csv("fiction_unique.csv",index=False)

# %%
#data break we can now use the csv files in a separate jupyter notebook to join, edit, load, etc
