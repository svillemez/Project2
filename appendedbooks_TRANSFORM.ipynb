# %%
import pandas as pd

# %%
file_path_fiction = "fiction_unique.csv"
df = pd.read_csv(file_path_fiction)

# %%
file_path_nonfiction = "nonfiction_unique.csv"
df2 = pd.read_csv(file_path_nonfiction)

# %%
all_books_df = df.append(df2)

# %%
all_books_df
# Out:
#                                      List   List_Date  \
# 0       Combined Print and E-Book Fiction  2020-09-27
# 1       Combined Print and E-Book Fiction  2020-09-13
# 2       Combined Print and E-Book Fiction  2020-05-03
# 3       Combined Print and E-Book Fiction  2020-02-02
# 4       Combined Print and E-Book Fiction  2020-09-06
# ..                                    ...         ...
# 128  Combined Print and E-Book Nonfiction  2020-09-27
# 129  Combined Print and E-Book Nonfiction  2020-08-16
# 130  Combined Print and E-Book Nonfiction  2020-05-24
# 131  Combined Print and E-Book Nonfiction  2020-05-10
# 132  Combined Print and E-Book Nonfiction  2020-08-02
#
#                           Title                           Author  \
# 0       WHERE THE CRAWDADS SING                      Delia Owens
# 1       LITTLE FIRES EVERYWHERE                       Celeste Ng
# 2    THE TATTOOIST OF AUSCHWITZ                   Heather Morris
# ...

# %%
all_books_df.to_csv("all_nyt_books.csv", index=False)
