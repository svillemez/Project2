# %%
# !pip install xlrd
# !pip install xlwt
# !pip install openpyxl
import pandas as pd
# Out:
# ...
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8920 sha256=861486ec4a3dd038a44c62fcff0a199916710a3b934ac4e55a78aaa41c29f543
#   Stored in directory: c:\users\adela\appdata\local\pip\cache\wheels\ef\92\e0\956c00decf3091294b8800d9104f6169a1adacfaafd122ed42
# Successfully built et-xmlfile
# ...

# %%
books_raw_data = pd.read_excel("data/books.xlsx")

# %%
books_raw_data
# Out:
#          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                       authors  original_publication_year  \
# ...

# %%
# books_raw_data['isbn13'].astype()

# %%
books_data = books_raw_data.dropna()
books_data
# Out:
#         id  book_id  best_book_id   work_id  books_count        isbn  \
# 0        1  2767052       2767052   2792775          272   439023483
# 1        2        3             3   4640799          491   439554934
# 2        3    41865         41865   3212258          226   316015849
# 3        4     2657          2657   3275794          487    61120081
# 4        5     4671          4671    245494         1356   743273567
# ...    ...      ...           ...       ...          ...         ...
# 9994  9995    15613         15613   2764239          199  1416523723
# 9995  9996  7130616       7130616   7392860           19   441019455
# 9996  9997   208324        208324   1084709           19  067973371X
# 9997  9998    77431         77431   2393986           60  039330762X
# 9998  9999  8565083       8565083  13433613            7    61711527
#
#             isbn13                       authors  original_publication_year  \
# ...

# %%
books_data['isbn13']=books_data['isbn13'].astype('int64')
books_data
# Out:
# C:\Users\Adela\anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         id  book_id  best_book_id   work_id  books_count        isbn  \
# 0        1  2767052       2767052   2792775          272   439023483
# 1        2        3             3   4640799          491   439554934
# 2        3    41865         41865   3212258          226   316015849
# 3        4     2657          2657   3275794          487    61120081
# 4        5     4671          4671    245494         1356   743273567
# ...    ...      ...           ...       ...          ...         ...
# ...

# %%
books_data_df = books_data[["book_id", "isbn", "isbn13", "authors", "original_publication_year", "original_title", "title", "average_rating", "ratings_count"]]
books_data_df
# Out:
#       book_id        isbn         isbn13                       authors  \
# 0     2767052   439023483  9780439023480               Suzanne Collins
# 1           3   439554934  9780439554930  J.K. Rowling, Mary GrandPr̩
# 2       41865   316015849  9780316015840               Stephenie Meyer
# 3        2657    61120081  9780061120080                    Harper Lee
# 4        4671   743273567  9780743273560           F. Scott Fitzgerald
# ...       ...         ...            ...                           ...
# 9994    15613  1416523723  9781416523730               Herman Melville
# 9995  7130616   441019455  9780441019460                 Ilona Andrews
# 9996   208324  067973371X  9780679733710                Robert A. Caro
# 9997    77431  039330762X  9780393307630               Patrick O'Brian
# 9998  8565083    61711527  9780061711530               Peggy Orenstein
#
#       original_publication_year  \
# 0                        2008.0
# 1                        1997.0
# ...

# %%
books_data_df.to_excel("data/book_data.xlsx", index=False)

# %%
ratings_raw_data = pd.read_csv("data/ratings.csv")
ratings_raw_data.head()
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4

# %%
ratings_data = ratings_raw_data.dropna()
ratings_data.head()
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4

# %%
ratings_data_df = ratings_data[["book_id", "rating"]]
ratings_data_df
# Out:
#         book_id  rating
# 0             1       5
# 1             1       3
# 2             1       5
# 3             1       4
# 4             1       4
# ...         ...     ...
# 981751    10000       5
# 981752    10000       4
# 981753    10000       5
# 981754    10000       5
# 981755    10000       1
#
# [981756 rows x 2 columns]

# %%
ratings_data_df.to_csv("data/ratings_data.csv", index=False)
